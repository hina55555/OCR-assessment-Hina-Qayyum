# %% [markdown]
# # Step 1: Processing the raw data

# %% [markdown]
# ## `process_OCR_data_files(df)`
#
# ### Description:
# This function processes Optical Character Recognition (OCR) data stored in a DataFrame. It performs various text analysis tasks including part-of-speech (PoS) analysis, abbreviation lookup from X1.json file for all the synonyms, date extraction, and chunking based on dates. The processed data is then filtered based on the latest date and stored in CSV files.
#
# ### Parameters:
# - `df` (DataFrame): The input DataFrame containing OCR data.
#
# ### Returns:
# - `processed_data` (DataFrame): The processed and filtered data stored in a DataFrame.
#
# ### Working:
#
# 1. **Perform PoS Analysis**:
#    - The function first performs PoS analysis on the text data using the spaCy library.
#
# 2. **Load Abbreviation Lookup Data**:
#    - It loads abbreviation lookup data from a JSON file ('X1.json').
#
# 3. **Find Abbreviations**:
#    - For each token in the DataFrame, the function looks up its abbreviation based on the loaded data and adds it as a new column.
#
# 4. **Extract Dates**:
#    - Dates are extracted from the text using regular expressions for the format 'dd/mm/yyyy' or 'dd/mm/yy'.
#
# 5. **Check Chronological Order**:
#    - It checks if the extracted dates are in chronological order.
#
# 6. **Chunking**:
#    - The DataFrame is divided into chunks based on non-empty dates. If no non-empty dates are found, all rows are placed in a single chunk.
#
# 7. **Concatenate Chunks**:
#    - All chunks are concatenated into a single DataFrame.
#
# 8. **Filter Data**:
#    - The function identifies the latest date among the extracted dates and filters the data to keep only those rows with that date.
#
# 9. **Store Discarded Data**:
#    - Dates of discarded chunks are stored for reference.
#
# 10. **Write to CSV**:
#     - Filtered data chunks are written to CSV files in a directory named 'files'.
#
# 11. **Read from CSV**:
#     - The function reads the first filtered chunk from the CSV file if available.
#
# ### Example Usage:
# ```python
# # Load DataFrame with OCR data
# df_data = ...
#
# # Process OCR data
# processed_data = process_OCR_data_files(df_data)

# %%
import pandas as pd
import glob
import os
import pandas as pd
import spacy
import en_core_web_sm
import json
import re
from datetime import datetime

# Define the function to process OCR data files
def process_OCR_data_files(df):
    # Step 1 – Perform PoS Analysis
    # Initialize an empty list to store features
    features = []
    # Load English language model
    nlp = en_core_web_sm.load()
    # Iterate over each text in the DataFrame
    for text in df['text']:
        # Process text with spaCy
        doc = nlp(text)
        # Iterate over each token in the document
        for token in doc:
            # Append token and its part-of-speech tag to features list
            features.append({'token': token.text, 'pos': token.pos_})
    # Create a DataFrame from the features list
    df_pos = pd.DataFrame.from_records(features)

    # Load X1.json for abbreviation lookup
    with open('X1.json', 'r') as f:
        data = json.load(f)

    # Function to find abbreviation for a token
    def find_abbreviation(token):
        for item in data:
            if token in item['Synonyms']:
                return item['Abbreviation']
        return None

    # Apply the function to add a new column with abbreviations
    df_pos['Abbreviation'] = df_pos['token'].apply(find_abbreviation)

    # Function to extract dates from text using regular expressions
    def extract_dates(text):
        # Regular expression for date format (dd/mm/yyyy or dd/mm/yy)
        pattern = r'\b(\d{1,2}/\d{1,2}/\d{2,4})\b'
        # Find all matches of date pattern in the text
        matches = re.findall(pattern, text)
        dates = []
        for match in matches:
            try:
                # Try parsing with different date formats
                dates.append(datetime.strptime(match, '%d/%m/%Y'))
            except ValueError:
                pass  # Skip if date format is not recognized
        return dates

    # Apply the function to extract dates from 'token' column
    df_pos['dates'] = df_pos['token'].apply(extract_dates)

    # Check if dates are in chronological order
    all_dates = [date for sublist in df_pos['dates'] for date in sublist]
    chronological_order = all(all_dates[i] <= all_dates[i+1] for i in range(len(all_dates)-1))

    if chronological_order:
        print("Dates are in chronological order.")
    else:
        print("Dates are not in chronological order.")

    # Function to get indexes of rows with non-empty dates
    def non_empty_dates_indexes(df):
        return df[df['dates'].apply(lambda x: len(x) > 0)].index.tolist()

    # Copy DataFrame for manipulation
    temp = df_pos.copy()

    # Get indexes of rows with non-empty dates
    indexes_with_non_empty_dates = non_empty_dates_indexes(temp)
    print(indexes_with_non_empty_dates)

    # Check if non-empty dates exist
    if indexes_with_non_empty_dates:
        # Function to generate tuples for date intervals
        def generate_tuples(lst):
            tuples = [(0, lst[0])]
            for i in range(1, len(lst)):
                tuples.append((lst[i-1], lst[i]))
            return tuples

        lst = indexes_with_non_empty_dates
        tuples = generate_tuples(lst)
        date_intervals = tuples
        print("")
        print(date_intervals)

        # Function to divide dataframe based on index ranges
        def divide_dataframe(df, index_ranges):
            dataframes = []
            for start, end in index_ranges:
                chunk = df.iloc[start:end]
                dataframes.append(chunk)
            return dataframes

        # Divide DataFrame into chunks based on date intervals
        chunks = divide_dataframe(temp, date_intervals)
    else:
        # If no non-empty dates exist, create a single chunk with all rows
        chunks = [temp]

    # Print chunks
    for i, chunk in enumerate(chunks):
        print(f"Chunk {i+1}:")
        print(chunk)

    # Concatenate all chunks into a single DataFrame
    concatenated_df = pd.concat(chunks, ignore_index=True)

    # Find the latest date
    latest_date = concatenated_df['dates'].max()

    # Filter chunks to keep only those with the latest date
    filtered_chunks = [chunk for chunk in chunks if chunk['dates'].max() == latest_date]

    # Find and store dates of discarded chunks
    discarded_dates = [chunk['dates'].max() for chunk in chunks if chunk['dates'].max() != latest_date]

    # Check if 'files' directory exists, if not create it
    if not os.path.exists('files'):
        os.makedirs('files')

    # Print information about the chunks
    if len(filtered_chunks) > 1:
        print("Multiple chunks with identical latest dates are added.")
    else:
        print("Only one chunk is added.")

    # Print the number of discarded chunks and their dates
    if len(discarded_dates) > 0:
        print(f"{len(discarded_dates)} chunks were discarded.")
        print("Dates of discarded chunks:")
        for date in discarded_dates:
            print(date)

    # Write filtered chunks to CSV
    for i, chunk in enumerate(filtered_chunks):
        print(f"Chunk {i+1}:")
        print(chunk)
        pd.DataFrame(chunk).to_csv(f"./files/data_{FILE_NAME}.csv", index=False)

    # Read the first filtered chunk from CSV
    if len(filtered_chunks) > 0:
        return pd.read_csv(f"./files/data_{FILE_NAME}.csv")
    else:
        return pd.DataFrame()

# Iterate over each file in the 'OCR data' directory
for file_path in glob.glob('./OCR data/*.txt'):
    # Load data from the current file

    FILE_NAME = file_path.split("/",3)[2][:-4]
    
    with open(file_path, 'r') as file:
        data = [line.strip() for line in file.readlines()]
    # Create a DataFrame from the loaded data
    df_data = pd.DataFrame(data, columns=['text'])
    # Process the OCR data
    processed_data = process_OCR_data_files(df_data)
    # Optional: You can do further processing or analysis with the processed data
# Out:
# Dates are in chronological order.
# []
# Chunk 1:
#         token    pos Abbreviation dates
# 0     Patient  PROPN         None    []
# 1        Name  PROPN         None    []
# 2          ee    ADP         None    []
# 3     Barcode  PROPN         None    []
# 4           ;  PUNCT         None    []
# ..        ...    ...          ...   ...
# 438   Medical  PROPN         None    []
# 439      Care  PROPN         None    []
# 440        in    ADP         None    []
# 441  Diabetes  PROPN         None    []
# 442      2015    NUM         None    []
#
# [443 rows x 4 columns]
# Only one chunk is added.
# Chunk 1:
#         token    pos Abbreviation dates
# 0     Patient  PROPN         None    []
# 1        Name  PROPN         None    []
# 2          ee    ADP         None    []
# 3     Barcode  PROPN         None    []
# 4           ;  PUNCT         None    []
# ..        ...    ...          ...   ...
# 438   Medical  PROPN         None    []
# 439      Care  PROPN         None    []
# 440        in    ADP         None    []
# 441  Diabetes  PROPN         None    []
# 442      2015    NUM         None    []
#
# [443 rows x 4 columns]
# Dates are in chronological order.
# []
# Chunk 1:
#         token    pos Abbreviation dates
# 0       Peghy   NOUN         None    []
# 1           «  PUNCT         None    []
# 2          Ao  PROPN         None    []
# 3          ¢4   NOUN         None    []
# 4          AG  PROPN         None    []
# ...       ...    ...          ...   ...
# 1907        :  PUNCT         None    []
# 1908        7    NUM         None    []
# 1909       of    ADP         None    []
# 1910        7    NUM         None    []
# 1911  REMOVED  PROPN         None    []
#
# [1912 rows x 4 columns]
# Only one chunk is added.
# Chunk 1:
#         token    pos Abbreviation dates
# 0       Peghy   NOUN         None    []
# 1           «  PUNCT         None    []
# 2          Ao  PROPN         None    []
# 3          ¢4   NOUN         None    []
# 4          AG  PROPN         None    []
# ...       ...    ...          ...   ...
# 1907        :  PUNCT         None    []
# 1908        7    NUM         None    []
# 1909       of    ADP         None    []
# 1910        7    NUM         None    []
# 1911  REMOVED  PROPN         None    []
#
# [1912 rows x 4 columns]
# Dates are not in chronological order.
# [40, 43, 46, 168, 171, 174, 303, 306, 309, 697, 700, 703, 887, 890, 893, 1050, 1053, 1056, 1417, 1420, 1423, 1739, 1742, 1745, 1835, 1838, 1841, 1949, 1952, 1955, 2183, 2186, 2189, 2508, 2511, 2514, 2897, 2900, 2903, 3083, 3086, 3089, 3439, 3442, 3445, 3539, 3542, 3545, 3679, 3682, 3685, 3914, 3917, 3920, 4078, 4081, 4084, 4182, 4185, 4188, 4360, 4363, 4366, 4489, 4492, 4495, 4599, 4602, 4605, 4718, 4721, 4724, 5084, 5087, 5090, 5178, 5226, 5229, 5232, 5351, 5354, 5357, 5711, 5714, 5717, 5760, 5766, 5824, 6060, 6063, 6066, 6109, 6115, 6173, 6413, 6416, 6419, 6428, 6458, 6555, 6603, 6606, 6609, 6622, 6651, 6748]
#
# [(0, 40), (40, 43), (43, 46), (46, 168), (168, 171), (171, 174), (174, 303), (303, 306), (306, 309), (309, 697), (697, 700), (700, 703), (703, 887), (887, 890), (890, 893), (893, 1050), (1050, 1053), (1053, 1056), (1056, 1417), (1417, 1420), (1420, 1423), (1423, 1739), (1739, 1742), (1742, 1745), (1745, 1835), (1835, 1838), (1838, 1841), (1841, 1949), (1949, 1952), (1952, 1955), (1955, 2183), (2183, 2186), (2186, 2189), (2189, 2508), (2508, 2511), (2511, 2514), (2514, 2897), (2897, 2900), (2900, 2903), (2903, 3083), (3083, 3086), (3086, 3089), (3089, 3439), (3439, 3442), (3442, 3445), (3445, 3539), (3539, 3542), (3542, 3545), (3545, 3679), (3679, 3682), (3682, 3685), (3685, 3914), (3914, 3917), (3917, 3920), (3920, 4078), (4078, 4081), (4081, 4084), (4084, 4182), (4182, 4185), (4185, 4188), (4188, 4360), (4360, 4363), (4363, 4366), (4366, 4489), (4489, 4492), (4492, 4495), (4495, 4599), (4599, 4602), (4602, 4605), (4605, 4718), (4718, 4721), (4721, 4724), (4724, 5084), (5084, 5087), (5087, 5090), (5090, 5178), (5178, 5226), (5226, 5229), (5229, 5232), (5232, 5351), (5351, 5354), (5354, 5357), (5357, 5711), (5711, 5714), (5714, 5717), (5717, 5760), (5760, 5766), (5766, 5824), (5824, 6060), (6060, 6063), (6063, 6066), (6066, 6109), (6109, 6115), (6115, 6173), (6173, 6413), (6413, 6416), (6416, 6419), (6419, 6428), (6428, 6458), (6458, 6555), (6555, 6603), (6603, 6606), (6606, 6609), (6609, 6622), (6622, 6651), (6651, 6748)]
# Chunk 1:
#              token    pos Abbreviation dates
# 0          Patient  PROPN         None    []
# 1           Health  PROPN         None    []
# 2          Summary  PROPN         None    []
# 3          removed   VERB         None    []
# 4          removed   VERB         None    []
# 5           D.O.B.  PROPN         None    []
# 6                :  PUNCT         None    []
# 7           Record  PROPN         None    []
# 8               No  PROPN         None    []
# 9                .  PUNCT         None    []
# 10               :  PUNCT         None    []
# 11            Home  PROPN         None    []
# 12           Phone  PROPN         None    []
# 13               :  PUNCT         None    []
# 14            Work   VERB         None    []
# 15           Phone  PROPN         None    []
# 16               :  PUNCT         None    []
# 17         removed   VERB         None    []
# 18         Printed   VERB         None    []
# 19              on    ADP         None    []
# 20            27th    ADJ         None    []
# 21        February  PROPN         None    []
# 22            2024    NUM         None    []
# 23  Investigations   NOUN         None    []
# 24               :  PUNCT         None    []
# 25         removed   VERB         None    []
# 26         removed   VERB         None    []
# 27         removed   VERB         None    []
# 28          remoed   VERB         None    []
# 29      Laboratory   NOUN         None    []
# 30               :  PUNCT         None    []
# 31             dhm   VERB         None    []
# 32         removed   VERB         None    []
# 33            Name   NOUN         None    []
# 34              of    ADP         None    []
# 35            Test   NOUN         None    []
# 36               :  PUNCT         None    []
# 37             MSU  PROPN         None    []
# 38       Requested   VERB         None    []
# 39               :  PUNCT         None    []
# Chunk 2:
#          token    pos Abbreviation                  dates
# 40  30/01/2024    NUM         None  [2024-01-30 00:00:00]
# 41   Collected   VERB         None                     []
# 42           :  PUNCT         None                     []
# Chunk 3:
#          token    pos Abbreviation                  dates
# 43  30/01/2024    NUM         None  [2024-01-30 00:00:00]
# 44    Reported   VERB         None                     []
# 45           :  PUNCT         None                     []
# Chunk 4:
#           token    pos Abbreviation                  dates
# 46   13/02/2024    NUM         None  [2024-02-13 00:00:00]
# 47        17:17    NUM         None                     []
# 48     Clinical    ADJ         None                     []
# 49        notes   NOUN         None                     []
# 50            :  PUNCT         None                     []
# ..          ...    ...          ...                    ...
# 163         IgG  PROPN         GGLO                     []
# 164           ,  PUNCT         None                     []
# 165         IgM  PROPN         None                     []
# 166   Requested   VERB         None                     []
# 167           :  PUNCT         None                     []
#
# [122 rows x 4 columns]
# Chunk 5:
#           token    pos Abbreviation                  dates
# 168  30/01/2024    NUM         None  [2024-01-30 00:00:00]
# 169   Collected   VERB         None                     []
# 170           :  PUNCT         None                     []
# Chunk 6:
#           token    pos Abbreviation                  dates
# 171  31/01/2024    NUM         None  [2024-01-31 00:00:00]
# 172    Reported   VERB         None                     []
# 173           :  PUNCT         None                     []
# Chunk 7:
#             token    pos Abbreviation                  dates
# 174    13/02/2024    NUM         None  [2024-02-13 00:00:00]
# 175         17:17    NUM         None                     []
# 176      Clinical    ADJ         None                     []
# 177         notes   NOUN         None                     []
# 178             :  PUNCT         None                     []
# ..            ...    ...          ...                    ...
# 298          Test   NOUN         None                     []
# 299             :  PUNCT         None                     []
# 300  Biochemistry  PROPN         None                     []
# 301     Requested   VERB         None                     []
# 302             :  PUNCT         None                     []
#
# [129 rows x 4 columns]
# Chunk 8:
#           token    pos Abbreviation                  dates
# 303  30/01/2024    NUM         None  [2024-01-30 00:00:00]
# 304   Collected   VERB         None                     []
# 305           :  PUNCT         None                     []
# Chunk 9:
#           token    pos Abbreviation                  dates
# 306  31/01/2024    NUM         None  [2024-01-31 00:00:00]
# 307    Reported   VERB         None                     []
# 308           :  PUNCT         None                     []
# Chunk 10:
#           token    pos Abbreviation                  dates
# 309  13/02/2024    NUM         None  [2024-02-13 00:00:00]
# 310       17:17    NUM         None                     []
# 311    Clinical    ADJ         None                     []
# 312       notes   NOUN         None                     []
# 313           :  PUNCT         None                     []
# ..          ...    ...          ...                    ...
# 692           :  PUNCT         None                     []
# 693           _      X         None                     []
# 694     Glucose   NOUN         None                     []
# 695   Requested   VERB         None                     []
# 696           :  PUNCT         None                     []
#
# [388 rows x 4 columns]
# Chunk 11:
#           token    pos Abbreviation                  dates
# 697  30/01/2024    NUM         None  [2024-01-30 00:00:00]
# 698   Collected   VERB         None                     []
# 699           :  PUNCT         None                     []
# Chunk 12:
#           token    pos Abbreviation                  dates
# 700  31/01/2024    NUM         None  [2024-01-31 00:00:00]
# 701    Reported   VERB         None                     []
# 702           :  PUNCT         None                     []
# Chunk 13:
#           token    pos Abbreviation                  dates
# 703  13/02/2024    NUM         None  [2024-02-13 00:00:00]
# 704       17:17    NUM         None                     []
# 705    Clinical    ADJ         None                     []
# 706       notes   NOUN         None                     []
# 707           :  PUNCT         None                     []
# ..          ...    ...          ...                    ...
# 882           :  PUNCT         None                     []
# 883        Iron  PROPN         Fe3+                     []
# 884     Studies   NOUN         None                     []
# 885   Requested   VERB         None                     []
# 886           :  PUNCT         None                     []
#
# [184 rows x 4 columns]
# Chunk 14:
#           token    pos Abbreviation                  dates
# 887  30/01/2024    NUM         None  [2024-01-30 00:00:00]
# 888   Collected   VERB         None                     []
# 889           :  PUNCT         None                     []
# Chunk 15:
#           token    pos Abbreviation                  dates
# 890  31/01/2024    NUM         None  [2024-01-31 00:00:00]
# 891    Reported   VERB         None                     []
# 892           :  PUNCT         None                     []
# Chunk 16:
#            token    pos Abbreviation                  dates
# 893   13/02/2024    NUM         None  [2024-02-13 00:00:00]
# 894        17:17    NUM         None                     []
# 895     Clinical    ADJ         None                     []
# 896        notes   NOUN         None                     []
# 897            :  PUNCT         None                     []
# ...          ...    ...          ...                    ...
# 1045      Lipids  PROPN         None                     []
# 1046       HDL(s    NUM         None                     []
# 1047           )  PUNCT         None                     []
# 1048   Requested   VERB         None                     []
# 1049           :  PUNCT         None                     []
#
# [157 rows x 4 columns]
# Chunk 17:
#            token    pos Abbreviation                  dates
# 1050  30/01/2024    NUM         None  [2024-01-30 00:00:00]
# 1051   Collected   VERB         None                     []
# 1052           :  PUNCT         None                     []
# Chunk 18:
#            token    pos Abbreviation                  dates
# 1053  31/01/2024    NUM         None  [2024-01-31 00:00:00]
# 1054    Reported   VERB         None                     []
# 1055           :  PUNCT         None                     []
# Chunk 19:
#             token    pos Abbreviation                  dates
# 1056   13/02/2024    NUM         None  [2024-02-13 00:00:00]
# 1057        17:17    NUM         None                     []
# 1058     Clinical    ADJ         None                     []
# 1059        notes   NOUN         None                     []
# 1060            :  PUNCT         None                     []
# ...           ...    ...          ...                    ...
# 1412         Test   NOUN         None                     []
# 1413            :  PUNCT         None                     []
# 1414  Haematology  PROPN         None                     []
# 1415    Requested   VERB         None                     []
# 1416            :  PUNCT         None                     []
#
# [361 rows x 4 columns]
# Chunk 20:
#            token    pos Abbreviation                  dates
# 1417  30/01/2024    NUM         None  [2024-01-30 00:00:00]
# 1418   Collected   VERB         None                     []
# 1419           :  PUNCT         None                     []
# Chunk 21:
#            token    pos Abbreviation                  dates
# 1420  31/01/2024    NUM         None  [2024-01-31 00:00:00]
# 1421    Reported   VERB         None                     []
# 1422           :  PUNCT         None                     []
# Chunk 22:
#            token    pos Abbreviation                  dates
# 1423  13/02/2024    NUM         None  [2024-02-13 00:00:00]
# 1424       17:17    NUM         None                     []
# 1425    Clinical    ADJ         None                     []
# 1426       notes   NOUN         None                     []
# 1427           :  PUNCT         None                     []
# ...          ...    ...          ...                    ...
# 1734         Hep  PROPN         None                     []
# 1735           B  PROPN         None                     []
# 1736    Serology   NOUN         None                     []
# 1737   Requested   VERB         None                     []
# 1738           :  PUNCT         None                     []
#
# [316 rows x 4 columns]
# Chunk 23:
#            token    pos Abbreviation                  dates
# 1739  30/01/2024    NUM         None  [2024-01-30 00:00:00]
# 1740   Collected   VERB         None                     []
# 1741           :  PUNCT         None                     []
# Chunk 24:
#            token    pos Abbreviation                  dates
# 1742  31/01/2024    NUM         None  [2024-01-31 00:00:00]
# 1743    Reported   VERB         None                     []
# 1744           :  PUNCT         None                     []
# Chunk 25:
#            token    pos Abbreviation                  dates
# 1745  13/02/2024    NUM         None  [2024-02-13 00:00:00]
# 1746       17:17    NUM         None                     []
# 1747    Clinical    ADJ         None                     []
# 1748       notes   NOUN         None                     []
# 1749           :  PUNCT         None                     []
# ...          ...    ...          ...                    ...
# 1830           :  PUNCT         None                     []
# 1831     Thyroid  PROPN         None                     []
# 1832    Function  PROPN         None                     []
# 1833   Requested   VERB         None                     []
# 1834           :  PUNCT         None                     []
#
# [90 rows x 4 columns]
# Chunk 26:
#            token    pos Abbreviation                  dates
# 1835  30/01/2024    NUM         None  [2024-01-30 00:00:00]
# 1836   Collected   VERB         None                     []
# 1837           :  PUNCT         None                     []
# Chunk 27:
#            token    pos Abbreviation                  dates
# 1838  31/01/2024    NUM         None  [2024-01-31 00:00:00]
# 1839    Reported   VERB         None                     []
# 1840           :  PUNCT         None                     []
# Chunk 28:
#            token    pos Abbreviation                  dates
# 1841  13/02/2024    NUM         None  [2024-02-13 00:00:00]
# 1842       17:17    NUM         None                     []
# 1843    Clinical    ADJ         None                     []
# 1844       notes   NOUN         None                     []
# 1845           :  PUNCT         None                     []
# ...          ...    ...          ...                    ...
# 1944         Vit  PROPN         None                     []
# 1945         D(s  PROPN         None                     []
# 1946           )  PUNCT         None                     []
# 1947   Requested   VERB         None                     []
# 1948           :  PUNCT         None                     []
#
# [108 rows x 4 columns]
# Chunk 29:
#            token    pos Abbreviation                  dates
# 1949  30/01/2024    NUM         None  [2024-01-30 00:00:00]
# 1950   Collected   VERB         None                     []
# 1951           :  PUNCT         None                     []
# Chunk 30:
#            token    pos Abbreviation                  dates
# 1952  31/01/2024    NUM         None  [2024-01-31 00:00:00]
# 1953    Reported   VERB         None                     []
# 1954           :  PUNCT         None                     []
# Chunk 31:
#             token    pos Abbreviation                  dates
# 1955   13/02/2024    NUM         None  [2024-02-13 00:00:00]
# 1956        17:17    NUM         None                     []
# 1957     Clinical    ADJ         None                     []
# 1958        notes   NOUN         None                     []
# 1959            :  PUNCT         None                     []
# ...           ...    ...          ...                    ...
# 2178         Test   NOUN         None                     []
# 2179            :  PUNCT         None                     []
# 2180  Haematology  PROPN         None                     []
# 2181    Requested   VERB         None                     []
# 2182            :  PUNCT         None                     []
#
# [228 rows x 4 columns]
# Chunk 32:
#            token    pos Abbreviation                  dates
# 2183  30/01/2024    NUM         None  [2024-01-30 00:00:00]
# 2184   Collected   VERB         None                     []
# 2185           :  PUNCT         None                     []
# Chunk 33:
#            token    pos Abbreviation                  dates
# 2186  31/01/2024    NUM         None  [2024-01-31 00:00:00]
# 2187    Reported   VERB         None                     []
# 2188           :  PUNCT         None                     []
# Chunk 34:
#              token    pos Abbreviation                  dates
# 2189    31/01/2024    NUM         None  [2024-01-31 00:00:00]
# 2190         11:47    NUM         None                     []
# 2191      Clinical    ADJ         None                     []
# 2192         notes   NOUN         None                     []
# 2193             :  PUNCT         None                     []
# ...            ...    ...          ...                    ...
# 2503          Test   NOUN         None                     []
# 2504             :  PUNCT         None                     []
# 2505  Biochemistry  PROPN         None                     []
# 2506     Requested   VERB         None                     []
# 2507             :  PUNCT         None                     []
#
# [319 rows x 4 columns]
# Chunk 35:
#            token    pos Abbreviation                  dates
# 2508  30/01/2024    NUM         None  [2024-01-30 00:00:00]
# 2509   Collected   VERB         None                     []
# 2510           :  PUNCT         None                     []
# Chunk 36:
#            token    pos Abbreviation                  dates
# 2511  31/01/2024    NUM         None  [2024-01-31 00:00:00]
# 2512    Reported   VERB         None                     []
# 2513           :  PUNCT         None                     []
# Chunk 37:
#            token    pos Abbreviation                  dates
# 2514  31/01/2024    NUM         None  [2024-01-31 00:00:00]
# 2515       12:17    NUM         None                     []
# 2516    Clinical    ADJ         None                     []
# 2517       notes   NOUN         None                     []
# 2518           :  PUNCT         None                     []
# ...          ...    ...          ...                    ...
# 2892           :  PUNCT         None                     []
# 2893           _  PUNCT         None                     []
# 2894     Glucose    NUM         None                     []
# 2895   Requested   VERB         None                     []
# 2896           :  PUNCT         None                     []
#
# [383 rows x 4 columns]
# Chunk 38:
#            token    pos Abbreviation                  dates
# 2897  30/01/2024    NUM         None  [2024-01-30 00:00:00]
# 2898   Collected   VERB         None                     []
# 2899           :  PUNCT         None                     []
# Chunk 39:
#            token    pos Abbreviation                  dates
# 2900  31/01/2024    NUM         None  [2024-01-31 00:00:00]
# 2901    Reported   VERB         None                     []
# 2902           :  PUNCT         None                     []
# Chunk 40:
#            token    pos Abbreviation                  dates
# 2903  31/01/2024    NUM         None  [2024-01-31 00:00:00]
# 2904       12:17    NUM         None                     []
# 2905    Clinical    ADJ         None                     []
# 2906       notes   NOUN         None                     []
# 2907           :  PUNCT         None                     []
# ...          ...    ...          ...                    ...
# 3078      Lipids  PROPN         None                     []
# 3079       HDL(s    NUM         None                     []
# 3080           )  PUNCT         None                     []
# 3081   Requested   VERB         None                     []
# 3082           :  PUNCT         None                     []
#
# [180 rows x 4 columns]
# Chunk 41:
#            token    pos Abbreviation                  dates
# 3083  30/01/2024    NUM         None  [2024-01-30 00:00:00]
# 3084   Collected   VERB         None                     []
# 3085           :  PUNCT         None                     []
# Chunk 42:
#            token    pos Abbreviation                  dates
# 3086  31/01/2024    NUM         None  [2024-01-31 00:00:00]
# 3087    Reported   VERB         None                     []
# 3088           :  PUNCT         None                     []
# Chunk 43:
#            token    pos Abbreviation                  dates
# 3089  31/01/2024    NUM         None  [2024-01-31 00:00:00]
# 3090       12:17    NUM         None                     []
# 3091    Clinical    ADJ         None                     []
# 3092       notes   NOUN         None                     []
# 3093           :  PUNCT         None                     []
# ...          ...    ...          ...                    ...
# 3434         Hep  PROPN         None                     []
# 3435           B  PROPN         None                     []
# 3436    Serology   NOUN         None                     []
# 3437   Requested   VERB         None                     []
# 3438           :  PUNCT         None                     []
#
# [350 rows x 4 columns]
# Chunk 44:
#            token    pos Abbreviation                  dates
# 3439  30/01/2024    NUM         None  [2024-01-30 00:00:00]
# 3440   Collected   VERB         None                     []
# 3441           :  PUNCT         None                     []
# Chunk 45:
#            token    pos Abbreviation                  dates
# 3442  31/01/2024    NUM         None  [2024-01-31 00:00:00]
# 3443    Reported   VERB         None                     []
# 3444           :  PUNCT         None                     []
# Chunk 46:
#            token    pos Abbreviation                  dates
# 3445  01/02/2024    NUM         None  [2024-02-01 00:00:00]
# 3446       02:47    NUM         None                     []
# 3447    Clinical    ADJ         None                     []
# 3448       notes   NOUN         None                     []
# 3449           :  PUNCT         None                     []
# ...          ...    ...          ...                    ...
# 3534         IgG  PROPN         GGLO                     []
# 3535           ,  PUNCT         None                     []
# 3536         IgM  PROPN         None                     []
# 3537   Requested   VERB         None                     []
# 3538           :  PUNCT         None                     []
#
# [94 rows x 4 columns]
# Chunk 47:
#            token    pos Abbreviation                  dates
# 3539  30/01/2024    NUM         None  [2024-01-30 00:00:00]
# 3540   Collected   VERB         None                     []
# 3541           :  PUNCT         None                     []
# Chunk 48:
#            token    pos Abbreviation                  dates
# 3542  31/01/2024    NUM         None  [2024-01-31 00:00:00]
# 3543    Reported   VERB         None                     []
# 3544           :  PUNCT         None                     []
# Chunk 49:
#            token    pos Abbreviation                  dates
# 3545  01/02/2024    NUM         None  [2024-02-01 00:00:00]
# 3546       02:47    NUM         None                     []
# 3547    Clinical    ADJ         None                     []
# 3548       notes   NOUN         None                     []
# 3549           :  PUNCT         None                     []
# ...          ...    ...          ...                    ...
# 3674         Vit  PROPN         None                     []
# 3675         D(s  PROPN         None                     []
# 3676           )  PUNCT         None                     []
# 3677   Requested   VERB         None                     []
# 3678           :  PUNCT         None                     []
#
# [134 rows x 4 columns]
# Chunk 50:
#            token    pos Abbreviation                  dates
# 3679  30/01/2024    NUM         None  [2024-01-30 00:00:00]
# 3680   Collected   VERB         None                     []
# 3681           :  PUNCT         None                     []
# Chunk 51:
#            token    pos Abbreviation                  dates
# 3682  31/01/2024    NUM         None  [2024-01-31 00:00:00]
# 3683    Reported   VERB         None                     []
# 3684           :  PUNCT         None                     []
# Chunk 52:
#            token    pos Abbreviation                  dates
# 3685  01/02/2024    NUM         None  [2024-02-01 00:00:00]
# 3686       05:17    NUM         None                     []
# 3687    Clinical    ADJ         None                     []
# 3688       notes   NOUN         None                     []
# 3689           :  PUNCT         None                     []
# ...          ...    ...          ...                    ...
# 3909        Iron  PROPN         Fe3+                     []
# 3910     Studies   NOUN         None                     []
# 3911     removed   VERB         None                     []
# 3912   Requested   VERB         None                     []
# 3913           :  PUNCT         None                     []
#
# [229 rows x 4 columns]
# Chunk 53:
#            token    pos Abbreviation                  dates
# 3914  30/01/2024    NUM         None  [2024-01-30 00:00:00]
# 3915   Collected   VERB         None                     []
# 3916           :  PUNCT         None                     []
# Chunk 54:
#            token    pos Abbreviation                  dates
# 3917  31/01/2024    NUM         None  [2024-01-31 00:00:00]
# 3918    Reported   VERB         None                     []
# 3919           :  PUNCT         None                     []
# Chunk 55:
#            token    pos Abbreviation                  dates
# 3920  01/02/2024    NUM         None  [2024-02-01 00:00:00]
# 3921       02:47    NUM         None                     []
# 3922    Clinical    ADJ         None                     []
# 3923       notes   NOUN         None                     []
# 3924           :  PUNCT         None                     []
# ...          ...    ...          ...                    ...
# 4073           :  PUNCT         None                     []
# 4074     Thyroid  PROPN         None                     []
# 4075    Function  PROPN         None                     []
# 4076   Requested   VERB         None                     []
# 4077           :  PUNCT         None                     []
#
# [158 rows x 4 columns]
# Chunk 56:
#            token    pos Abbreviation                  dates
# 4078  30/01/2024    NUM         None  [2024-01-30 00:00:00]
# 4079   Collected   VERB         None                     []
# 4080           :  PUNCT         None                     []
# Chunk 57:
#            token    pos Abbreviation                  dates
# 4081  31/01/2024    NUM         None  [2024-01-31 00:00:00]
# 4082    Reported   VERB         None                     []
# 4083           :  PUNCT         None                     []
# Chunk 58:
#            token    pos Abbreviation                  dates
# 4084  01/02/2024    NUM         None  [2024-02-01 00:00:00]
# 4085       02:47    NUM         None                     []
# 4086    Clinical    ADJ         None                     []
# 4087       notes   NOUN         None                     []
# 4088           :  PUNCT         None                     []
# ...          ...    ...          ...                    ...
# 4177           :  PUNCT         None                     []
# 4178           _  PROPN         None                     []
# 4179   Pregnancy  PROPN         None                     []
# 4180   Requested   VERB         None                     []
# 4181           :  PUNCT         None                     []
#
# [98 rows x 4 columns]
# Chunk 59:
#            token    pos Abbreviation                  dates
# 4182  02/02/2024    NUM         None  [2024-02-02 00:00:00]
# 4183   Collected   VERB         None                     []
# 4184           :  PUNCT         None                     []
# Chunk 60:
#            token    pos Abbreviation                  dates
# 4185  02/02/2024    NUM         None  [2024-02-02 00:00:00]
# 4186    Reported   VERB         None                     []
# 4187           :  PUNCT         None                     []
# Chunk 61:
#              token    pos Abbreviation                  dates
# 4188    13/02/2024    NUM         None  [2024-02-13 00:00:00]
# 4189         17:17    NUM         None                     []
# 4190      Clinical    ADJ         None                     []
# 4191         notes   NOUN         None                     []
# 4192             :  PUNCT         None                     []
# ...            ...    ...          ...                    ...
# 4355          Test   NOUN         None                     []
# 4356             :  PUNCT         None                     []
# 4357  Biochemistry  PROPN         None                     []
# 4358     Requested   VERB         None                     []
# 4359             :  PUNCT         None                     []
#
# [172 rows x 4 columns]
# Chunk 62:
#            token    pos Abbreviation                  dates
# 4360  02/02/2024    NUM         None  [2024-02-02 00:00:00]
# 4361   Collected   VERB         None                     []
# 4362           :  PUNCT         None                     []
# Chunk 63:
#            token    pos Abbreviation                  dates
# 4363  02/02/2024    NUM         None  [2024-02-02 00:00:00]
# 4364    Reported   VERB         None                     []
# 4365           :  PUNCT         None                     []
# Chunk 64:
#            token    pos Abbreviation                  dates
# 4366  13/02/2024    NUM         None  [2024-02-13 00:00:00]
# 4367       17:17    NUM         None                     []
# 4368    Clinical    ADJ         None                     []
# 4369       notes   NOUN         None                     []
# 4370           :  PUNCT         None                     []
# ...          ...    ...          ...                    ...
# 4484          RU  PROPN         None                     []
# 4485           -  PUNCT         None                     []
# 4486        Malb  PROPN         None                     []
# 4487   Requested   VERB         None                     []
# 4488           :  PUNCT         None                     []
#
# [123 rows x 4 columns]
# Chunk 65:
#            token    pos Abbreviation                  dates
# 4489  02/02/2024    NUM         None  [2024-02-02 00:00:00]
# 4490   Collected   VERB         None                     []
# 4491           :  PUNCT         None                     []
# Chunk 66:
#            token    pos Abbreviation                  dates
# 4492  02/02/2024    NUM         None  [2024-02-02 00:00:00]
# 4493    Reported   VERB         None                     []
# 4494           :  PUNCT         None                     []
# Chunk 67:
#            token    pos Abbreviation                  dates
# 4495  13/02/2024    NUM         None  [2024-02-13 00:00:00]
# 4496       17:17    NUM         None                     []
# 4497    Clinical    ADJ         None                     []
# 4498       notes   NOUN         None                     []
# 4499           :  PUNCT         None                     []
# ...          ...    ...          ...                    ...
# 4594        Test   NOUN         None                     []
# 4595           :  PUNCT         None                     []
# 4596         MSU  PROPN         None                     []
# 4597   Requested   VERB         None                     []
# 4598           :  PUNCT         None                     []
#
# [104 rows x 4 columns]
# Chunk 68:
#            token    pos Abbreviation                  dates
# 4599  02/02/2024    NUM         None  [2024-02-02 00:00:00]
# 4600   Collected   VERB         None                     []
# 4601           :  PUNCT         None                     []
# Chunk 69:
#            token    pos Abbreviation                  dates
# 4602  02/02/2024    NUM         None  [2024-02-02 00:00:00]
# 4603    Reported   VERB         None                     []
# 4604           :  PUNCT         None                     []
# Chunk 70:
#              token    pos Abbreviation                  dates
# 4605    13/02/2024    NUM         None  [2024-02-13 00:00:00]
# 4606         17:17    NUM         None                     []
# 4607      Clinical    ADJ         None                     []
# 4608         notes   NOUN         None                     []
# 4609             :  PUNCT         None                     []
# ...            ...    ...          ...                    ...
# 4713          Test   NOUN         None                     []
# 4714             :  PUNCT         None                     []
# 4715  Biochemistry  PROPN         None                     []
# 4716     Requested   VERB         None                     []
# 4717             :  PUNCT         None                     []
#
# [113 rows x 4 columns]
# Chunk 71:
#            token    pos Abbreviation                  dates
# 4718  05/02/2024    NUM         None  [2024-02-05 00:00:00]
# 4719   Collected   VERB         None                     []
# 4720           :  PUNCT         None                     []
# Chunk 72:
#            token    pos Abbreviation                  dates
# 4721  05/02/2024    NUM         None  [2024-02-05 00:00:00]
# 4722    Reported   VERB         None                     []
# 4723           :  PUNCT         None                     []
# Chunk 73:
#            token    pos Abbreviation                  dates
# 4724  13/02/2024    NUM         None  [2024-02-13 00:00:00]
# 4725       17:17    NUM         None                     []
# 4726    Clinical    ADJ         None                     []
# 4727       notes   NOUN         None                     []
# 4728           :  PUNCT         None                     []
# ...          ...    ...          ...                    ...
# 5079           (  PUNCT         None                     []
# 5080           e   NOUN         None                     []
# 5081           )  PUNCT         None                     []
# 5082   Requested   VERB         None                     []
# 5083           :  PUNCT         None                     []
#
# [360 rows x 4 columns]
# Chunk 74:
#            token    pos Abbreviation                  dates
# 5084  02/02/2024    NUM         None  [2024-02-02 00:00:00]
# 5085   Collected   VERB         None                     []
# 5086           :  PUNCT         None                     []
# Chunk 75:
#            token    pos Abbreviation                  dates
# 5087  05/02/2024    NUM         None  [2024-02-05 00:00:00]
# 5088    Reported   VERB         None                     []
# 5089           :  PUNCT         None                     []
# Chunk 76:
#            token    pos Abbreviation                  dates
# 5090  13/02/2024    NUM         None  [2024-02-13 00:00:00]
# 5091       17:17    NUM         None                     []
# 5092     removed   VERB         None                     []
# 5093    Clinical    ADJ         None                     []
# 5094       notes   NOUN         None                     []
# ...          ...    ...          ...                    ...
# 5173       PTH(e   NOUN         None                     []
# 5174           )  PUNCT         None                     []
# 5175  collection   NOUN         None                     []
# 5176        date   NOUN         None                     []
# 5177           :  PUNCT         None                     []
#
# [88 rows x 4 columns]
# Chunk 77:
#                   token    pos Abbreviation                  dates
# 5178         05/02/2024    NUM         None  [2024-02-05 00:00:00]
# 5179              13:43    NUM         None                     []
# 5180               NATA  PROPN         None                     []
# 5181      Accreditation  PROPN         None                     []
# 5182                 No   PRON         None                     []
# 5183               2178    NUM         None                     []
# 5184              Tests  PROPN         None                     []
# 5185          Completed   VERB         None                     []
# 5186                  :  PUNCT         None                     []
# 5187                HCG  PROPN         None                     []
# 5188  Quant(s),Ca(s),RU  PROPN         None                     []
# 5189                  -  PUNCT         None                     []
# 5190               Malb  PROPN         None                     []
# 5191                  ,  PUNCT         None                     []
# 5192         PTH(e),MSU  PROPN         None                     []
# 5193                  ,  PUNCT         None                     []
# 5194             Urinel  PROPN         None                     []
# 5195                  ,  PUNCT         None                     []
# 5196             Urine2  PROPN         None                     []
# 5197                  ,  PUNCT         None                     []
# 5198             Urine3  PROPN         None                     []
# 5199              Tests   NOUN         None                     []
# 5200            Pending   VERB         None                     []
# 5201             Sample   NOUN         None                     []
# 5202            Pending   VERB         None                     []
# 5203            removed   VERB         None                     []
# 5204            removed   VERB         None                     []
# 5205            removed   VERB         None                     []
# 5206             remoed   VERB         None                     []
# 5207               Your   PRON         None                     []
# 5208          Reference   NOUN         None                     []
# 5209                  :  PUNCT         None                     []
# 5210                Lab   NOUN         None                     []
# 5211          Reference  PROPN         None                     []
# 5212                  :  PUNCT         None                     []
# 5213            removed   VERB         None                     []
# 5214         Laboratory   NOUN         None                     []
# 5215                  :  PUNCT         None                     []
# 5216                dhm   VERB         None                     []
# 5217            removed   VERB         None                     []
# 5218               Name   NOUN         None                     []
# 5219                 of    ADP         None                     []
# 5220               Test   NOUN         None                     []
# 5221                  :  PUNCT         None                     []
# 5222                  _  PUNCT         None                     []
# 5223            Glucose    NUM         None                     []
# 5224          Requested   VERB         None                     []
# 5225                  :  PUNCT         None                     []
# Chunk 78:
#            token    pos Abbreviation                  dates
# 5226  05/02/2024    NUM         None  [2024-02-05 00:00:00]
# 5227   Collected   VERB         None                     []
# 5228           :  PUNCT         None                     []
# Chunk 79:
#            token    pos Abbreviation                  dates
# 5229  05/02/2024    NUM         None  [2024-02-05 00:00:00]
# 5230    Reported   VERB         None                     []
# 5231           :  PUNCT         None                     []
# Chunk 80:
#            token    pos Abbreviation                  dates
# 5232  13/02/2024    NUM         None  [2024-02-13 00:00:00]
# 5233       17:17    NUM         None                     []
# 5234    Clinical    ADJ         None                     []
# 5235       notes   NOUN         None                     []
# 5236           :  PUNCT         None                     []
# ...          ...    ...          ...                    ...
# 5346       HDL(s    NUM         None                     []
# 5347           )  PUNCT         None                     []
# 5348     removed   VERB         None                     []
# 5349   Requested   VERB         None                     []
# 5350           :  PUNCT         None                     []
#
# [119 rows x 4 columns]
# Chunk 81:
#            token    pos Abbreviation                  dates
# 5351  05/02/2024    NUM         None  [2024-02-05 00:00:00]
# 5352   Collected   VERB         None                     []
# 5353           :  PUNCT         None                     []
# Chunk 82:
#            token    pos Abbreviation                  dates
# 5354  05/02/2024    NUM         None  [2024-02-05 00:00:00]
# 5355    Reported   VERB         None                     []
# 5356           :  PUNCT         None                     []
# Chunk 83:
#            token    pos Abbreviation                  dates
# 5357  13/02/2024    NUM         None  [2024-02-13 00:00:00]
# 5358       17:17    NUM         None                     []
# 5359    Clinical    ADJ         None                     []
# 5360       notes   NOUN         None                     []
# 5361           :  PUNCT         None                     []
# ...          ...    ...          ...                    ...
# 5706           :  PUNCT         None                     []
# 5707          BP  PROPN         None                     []
# 5708     Monitor  PROPN         None                     []
# 5709   Requested   VERB         None                     []
# 5710           :  PUNCT         None                     []
#
# [354 rows x 4 columns]
# Chunk 84:
#            token    pos Abbreviation                  dates
# 5711  03/02/2024    NUM         None  [2024-02-03 00:00:00]
# 5712   Collected   VERB         None                     []
# 5713           :  PUNCT         None                     []
# Chunk 85:
#            token    pos Abbreviation                  dates
# 5714  06/02/2024    NUM         None  [2024-02-06 00:00:00]
# 5715    Reported   VERB         None                     []
# 5716           :  PUNCT         None                     []
# Chunk 86:
#              token    pos Abbreviation                  dates
# 5717    13/02/2024    NUM         None  [2024-02-13 00:00:00]
# 5718         17:17    NUM         None                     []
# 5719      Clinical    ADJ         None                     []
# 5720         notes   NOUN         None                     []
# 5721             :  PUNCT         None                     []
# 5722             ?  PUNCT         None                     []
# 5723  HYPERTENSION  PROPN         None                     []
# 5724             ?  PUNCT         None                     []
# 5725       ANXIETY  PROPN         None                     []
# 5726       RELATED  PROPN         None                     []
# 5727             /    SYM         None                     []
# 5728         WHITE  PROPN         None                     []
# 5729          COAT  PROPN         None                     []
# 5730  HYPERTENSION  PROPN         None                     []
# 5731             (  PUNCT         None                     []
# 5732         NEEDS  PROPN         None                     []
# 5733     EXCLUDING   VERB         None                     []
# 5734             )  PUNCT         None                     []
# 5735       removed   VERB         None                     []
# 5736      Clinical    ADJ         None                     []
# 5737         Notes   NOUN         None                     []
# 5738             :  PUNCT         None                     []
# 5739             ?  PUNCT         None                     []
# 5740  HYPERTENSION  PROPN         None                     []
# 5741             ?  PUNCT         None                     []
# 5742       ANXIETY  PROPN         None                     []
# 5743       RELATED  PROPN         None                     []
# 5744             /    SYM         None                     []
# 5745         WHITE  PROPN         None                     []
# 5746          COAT  PROPN         None                     []
# 5747  HYPERTENSION  PROPN         None                     []
# 5748             (  PUNCT         None                     []
# 5749         NEEDS  PROPN         None                     []
# 5750     EXCLUDING   VERB         None                     []
# 5751             )  PUNCT         None                     []
# 5752    Ambulatory  PROPN         None                     []
# 5753         Blood  PROPN         None                     []
# 5754      Pressure  PROPN         None                     []
# 5755    Monitoring   NOUN         None                     []
# 5756         Start   VERB         None                     []
# 5757          date   NOUN         None                     []
# 5758           and  CCONJ         None                     []
# 5759          time   NOUN         None                     []
# Chunk 87:
#            token    pos Abbreviation                  dates
# 5760  05/02/2024    NUM         None  [2024-02-05 00:00:00]
# 5761       13:52    NUM         None                     []
# 5762         End   NOUN         None                     []
# 5763        date   NOUN         None                     []
# 5764         and  CCONJ         None                     []
# 5765        time   NOUN         None                     []
# Chunk 88:
#              token    pos Abbreviation                  dates
# 5766    06/02/2024    NUM         None  [2024-02-06 00:00:00]
# 5767         13:00    NUM         None                     []
# 5768   Medications   NOUN         None                     []
# 5769        Please   INTJ         None                     []
# 5770         refer   VERB         None                     []
# 5771            to    ADP         None                     []
# 5772       patient    ADJ         None                     []
# 5773         diary   NOUN         None                     []
# 5774           for    ADP         None                     []
# 5775       current    ADJ         None                     []
# 5776   medications   NOUN         None                     []
# 5777             .  PUNCT         None                     []
# 5778       Average    ADJ         None                     []
# 5779            BP   NOUN         None                     []
# 5780        127/85  PROPN         None                     []
# ...
# Chunk 27:
#            token    pos Abbreviation                  dates
# 1466  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 1467    Complete    ADJ         None                     []
# 1468           :  PUNCT         None                     []
# 1469       Final    ADJ         None                     []
# 1470    Specimen   NOUN         None                     []
# ...          ...    ...          ...                    ...
# 1582     Patient  PROPN         None                     []
# 1583     Address  PROPN         None                     []
# 1584           :  PUNCT         None                     []
# 1585       D.O.B  PROPN         None                     []
# 1586           :  PUNCT         None                     []
#
# [121 rows x 4 columns]
# Chunk 28:
#            token    pos Abbreviation                  dates
# 1609  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 1610        Date  PROPN         None                     []
# 1611   Performed   VERB         None                     []
# 1612           :  PUNCT         None                     []
# Chunk 29:
#            token    pos Abbreviation                  dates
# 1613  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 1614        Date  PROPN         None                     []
# 1615   Collected   VERB         None                     []
# 1616           :  PUNCT         None                     []
# Chunk 30:
#            token    pos Abbreviation                  dates
# 1617  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 1618           |   NOUN         None                     []
# 1619    Complete    ADJ         None                     []
# 1620           :  PUNCT         None                     []
# 1621       Final    ADJ         None                     []
# ...          ...    ...          ...                    ...
# 1904     Patient  PROPN         None                     []
# 1905     Address  PROPN         None                     []
# 1906           :  PUNCT         None                     []
# 1907       D.O.B  PROPN         None                     []
# 1908           :  PUNCT         None                     []
#
# [292 rows x 4 columns]
# Chunk 31:
#            token    pos Abbreviation                  dates
# 1931  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 1932        Date  PROPN         None                     []
# 1933   Performed   VERB         None                     []
# 1934           :  PUNCT         None                     []
# Chunk 32:
#            token    pos Abbreviation                  dates
# 1935  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 1936        Date  PROPN         None                     []
# 1937   Collected   VERB         None                     []
# 1938           :  PUNCT         None                     []
# Chunk 33:
#            token    pos Abbreviation                  dates
# 1939  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 1940    Complete    ADJ         None                     []
# 1941           :  PUNCT         None                     []
# 1942       Final    ADJ         None                     []
# 1943    Specimen   NOUN         None                     []
# ...          ...    ...          ...                    ...
# 2410     Patient  PROPN         None                     []
# 2411     Address  PROPN         None                     []
# 2412           :  PUNCT         None                     []
# 2413       D.O.B  PROPN         None                     []
# 2414           :  PUNCT         None                     []
#
# [476 rows x 4 columns]
# Chunk 34:
#            token    pos Abbreviation                  dates
# 2446  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 2447        Date  PROPN         None                     []
# 2448   Performed   VERB         None                     []
# 2449           :  PUNCT         None                     []
# Chunk 35:
#            token    pos Abbreviation                  dates
# 2450  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 2451        Date  PROPN         None                     []
# 2452   Collected   VERB         None                     []
# 2453           :  PUNCT         None                     []
# Chunk 36:
#            token    pos Abbreviation                  dates
# 2454  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 2455    Complete    ADJ         None                     []
# 2456           :  PUNCT         None                     []
# 2457       Final    ADJ         None                     []
# 2458    Specimen   NOUN         None                     []
# ...          ...    ...          ...                    ...
# 2569     Patient  PROPN         None                     []
# 2570     Address  PROPN         None                     []
# 2571           :  PUNCT         None                     []
# 2572       D.O.B  PROPN         None                     []
# 2573           :  PUNCT         None                     []
#
# [120 rows x 4 columns]
# Chunk 37:
#            token    pos Abbreviation                  dates
# 2591  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 2592           :  PUNCT         None                     []
# Chunk 38:
#             token    pos Abbreviation                  dates
# 2593   10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 2594     Clinical    ADJ         None                     []
# 2595  Information  PROPN         None                     []
# 2596            :  PUNCT         None                     []
# 2597        Clini  PROPN         None                     []
# ...           ...    ...          ...                    ...
# 2696    Pathology  PROPN         None                     []
# 2697           DR  PROPN         None                     []
# 2698            .  PUNCT         None                     []
# 2699         INNA  PROPN         None                     []
# 2700         LIEB  PROPN         None                     []
#
# [108 rows x 4 columns]
# Chunk 39:
#            token    pos Abbreviation                  dates
# 2701  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 2702    Complete    ADJ         None                     []
# 2703           :  PUNCT         None                     []
# 2704       Final    ADJ         None                     []
# 2705          30    NUM         None                     []
# 2706         Apr  PROPN         None                     []
# 2707          18    NUM         None                     []
# 2708       12:05    NUM         None                     []
# 2709           <      X         None                     []
# 2710         4.0    NUM         None                     []
# 2711    14721343    NUM         None                     []
# 2712          10    NUM         None                     []
# 2713         Dec  PROPN         None                     []
# 2714          18    NUM         None                     []
# 2715       15:36    NUM         None                     []
# 2716           <      X         None                     []
# 2717         4.0    NUM         None                     []
# 2718         ESR  PROPN         None                     []
# 2719           ,  PUNCT         None                     []
# 2720         CRP  PROPN         None                     []
# 2721           ,  PUNCT         None                     []
# 2722         CEA  PROPN         None                     []
# 2723           *  PROPN         None                     []
# 2724           ,  PUNCT         None                     []
# 2725         C19  PROPN         None                     []
# 2726           *  PROPN         None                     []
# 2727           ,  PUNCT         None                     []
# 2728         C15  PROPN         None                     []
# 2729           ,  PUNCT         None                     []
# 2730         125    NUM         None                     []
# 2731           *    NUM         None                     []
# 2732           ,  PUNCT         None                     []
# 2733         MBA  PROPN         None                     []
# 2734           *  PROPN         None                     []
# 2735           ,  PUNCT         None                     []
# 2736          FE  PROPN         None                     []
# 2737           *   NOUN         None                     []
# 2738           t   NOUN         None                     []
# 2739     Patient    ADJ         None                     []
# 2740        Name   NOUN         None                     []
# 2741           :  PUNCT         None                     []
# 2742     Patient  PROPN         None                     []
# 2743     Address  PROPN         None                     []
# 2744           :  PUNCT         None                     []
# 2745       D.O.B  PROPN         None                     []
# 2746           :  PUNCT         None                     []
# Chunk 40:
#            token    pos Abbreviation                  dates
# 2769  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 2770        Date  PROPN         None                     []
# 2771   Performed   VERB         None                     []
# 2772           :  PUNCT         None                     []
# Chunk 41:
#            token    pos Abbreviation                  dates
# 2773  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 2774           ‘  PUNCT         None                     []
# 2775        Date   NOUN         None                     []
# 2776   Collected   VERB         None                     []
# 2777           :  PUNCT         None                     []
# Chunk 42:
#            token    pos Abbreviation                  dates
# 2778  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 2779           .  PUNCT         None                     []
# 2780    Complete    ADJ         None                     []
# 2781           :  PUNCT         None                     []
# 2782       Final    ADJ         None                     []
# ...          ...    ...          ...                    ...
# 2907     Patient  PROPN         None                     []
# 2908     Address  PROPN         None                     []
# 2909           :  PUNCT         None                     []
# 2910       D.O.B  PROPN         None                     []
# 2911           :  PUNCT         None                     []
#
# [134 rows x 4 columns]
# Chunk 43:
#            token    pos Abbreviation                  dates
# 2934  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 2935        Date  PROPN         None                     []
# 2936   Performed   VERB         None                     []
# 2937           :  PUNCT         None                     []
# Chunk 44:
#            token    pos Abbreviation                  dates
# 2938  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 2939        Date  PROPN         None                     []
# 2940   Collected   VERB         None                     []
# 2941           :  PUNCT         None                     []
# Chunk 45:
#            token    pos Abbreviation                  dates
# 2942  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 2943    Complete    ADJ         None                     []
# 2944           :  PUNCT         None                     []
# 2945       Final    ADJ         None                     []
# 2946    Specimen   NOUN         None                     []
# ...          ...    ...          ...                    ...
# 3099     Patient  PROPN         None                     []
# 3100     Address  PROPN         None                     []
# 3101           ;  PUNCT         None                     []
# 3102       D.O.B  PROPN         None                     []
# 3103           :  PUNCT         None                     []
#
# [162 rows x 4 columns]
# Chunk 46:
#            token    pos Abbreviation                  dates
# 3135  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 3136        Date  PROPN         None                     []
# 3137   Performed   VERB         None                     []
# 3138           :  PUNCT         None                     []
# Chunk 47:
#            token    pos Abbreviation                  dates
# 3139  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 3140        Date  PROPN         None                     []
# 3141   Collected   VERB         None                     []
# 3142           :  PUNCT         None                     []
# Chunk 48:
#            token    pos Abbreviation                  dates
# 3143  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 3144    Complete    ADJ         None                     []
# 3145           :  PUNCT         None                     []
# 3146       Final    ADJ         None                     []
# 3147    Specimen   NOUN         None                     []
# ...          ...    ...          ...                    ...
# 3263     Patient  PROPN         None                     []
# 3264     Address  PROPN         None                     []
# 3265           ;  PUNCT         None                     []
# 3266       D.O.B  PROPN         None                     []
# 3267           :  PUNCT         None                     []
#
# [125 rows x 4 columns]
# Chunk 49:
#            token    pos Abbreviation                  dates
# 3290  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 3291        Date  PROPN         None                     []
# 3292   Performed   VERB         None                     []
# 3293           :  PUNCT         None                     []
# Chunk 50:
#            token    pos Abbreviation                  dates
# 3294  10/12/2018    NUM         None  [2018-12-10 00:00:00]
# 3295        Date  PROPN         None                     []
# 3296   Collected   VERB         None                     []
# 3297           :  PUNCT         None                     []
# Dates are in chronological order.
# [19, 393]
#
# [(0, 19), (19, 393)]
# Chunk 1:
#           token    pos Abbreviation dates
# 0     iilaverty  PROPN         None    []
# 1           -—-  PROPN         None    []
# 2     Pathology  PROPN         None    []
# 3        Report  PROPN         None    []
# 4       resuits   VERB         None    []
# 5         @RCPA    ADV         None    []
# 6     pathology   NOUN         None    []
# 7     ENQUIRIES   VERB         None    []
# 8           tet  PROPN         None    []
# 9        cramer   NOUN         None    []
# 10           NF  PROPN         None    []
# 11      removed   VERB         None    []
# 12      removed   VERB         None    []
# 13      removed   VERB         None    []
# 14        Phone   NOUN         None    []
# 15        D.O.B  PROPN         None    []
# 16  XXXXXXXXXXX  PROPN         None    []
# 17      removed   VERB         None    []
# 18     Reported   VERB         None    []
# Chunk 2:
#            token    pos Abbreviation                  dates
# 19    18/01/2024    NUM         None  [2024-01-18 00:00:00]
# 20         05:13    NUM         None                     []
# 21            PM   NOUN         None                     []
# 22         Tests   NOUN         None                     []
# 23     requested   VERB         None                     []
# ..           ...    ...          ...                    ...
# 388        D.O.B  PROPN         None                     []
# 389  XXXXXXXXXXX  PROPN         None                     []
# 390           Mm  PROPN         None                     []
# 391      removed   VERB         None                     []
# 392     Reported   VERB         None                     []
#
# [374 rows x 4 columns]
# Only one chunk is added.
# 1 chunks were discarded.
# Dates of discarded chunks:
# []
# Chunk 1:
#            token    pos Abbreviation                  dates
# 19    18/01/2024    NUM         None  [2024-01-18 00:00:00]
# 20         05:13    NUM         None                     []
# 21            PM   NOUN         None                     []
# 22         Tests   NOUN         None                     []
# 23     requested   VERB         None                     []
# ..           ...    ...          ...                    ...
# 388        D.O.B  PROPN         None                     []
# 389  XXXXXXXXXXX  PROPN         None                     []
# 390           Mm  PROPN         None                     []
# 391      removed   VERB         None                     []
# 392     Reported   VERB         None                     []
#
# [374 rows x 4 columns]

# %% [markdown]
# ## Hardest Parts and Challenges:
#
# ### PoS Analysis with spaCy:
# Performing Part-of-Speech (PoS) analysis using spaCy was challenging due to the complexity of natural language processing (NLP) tasks. It required understanding spaCy's API, tokenization, and parsing of text data.
#
# ### Date Extraction with Regular Expressions:
# Extracting dates from OCR text using regular expressions presented challenges due to variations in date formats and potential errors in recognition. Handling different date formats ('dd/mm/yyyy' or 'dd/mm/yy') required careful consideration and robust error handling.
#
# ### Chunking Based on Dates:
# Chunking the DataFrame based on dates was complex, especially when dealing with varying intervals between dates. The algorithm had to handle scenarios with non-contiguous date ranges and ensure the integrity of data chunks.
#
# ### Handling Abbreviation Lookup:
# Implementing abbreviation lookup involved loading data from a JSON file and efficiently searching for abbreviations based on token synonyms. Managing the data structure and optimizing the lookup process were challenging tasks.
#
# ### Writing to CSV Files:
# Writing filtered data chunks to CSV files required managing file paths, ensuring file integrity, and handling potential errors during file I/O operations. Ensuring that each chunk was correctly written to the designated CSV file was crucial for data preservation.
#
# ### Chronological Order Validation:
# Validating if dates extracted from the OCR text were in chronological order posed a challenge, especially when dealing with large datasets. Ensuring the accuracy of date ordering required careful iteration and comparison of date values.
#
# ### Error Handling and Robustness:
# Ensuring robust error handling throughout the codebase was essential to handle various edge cases, such as invalid dates, missing abbreviation data, or unexpected text formats. Implementing robust error handling mechanisms enhanced the reliability of the function.
#
# ### Documentation and Code Clarity:
# Documenting the code and maintaining clarity in function descriptions, parameter usage, and return values were critical for readability and understanding. Clear documentation facilitated collaboration and maintenance of the codebase.
#
# ### Performance Optimization:
# Optimizing the performance of date extraction, chunking, and file operations was necessary to enhance the efficiency of the function, especially when dealing with large OCR datasets. Implementing efficient algorithms and data structures helped improve overall performance.
#
# ### Cross-Platform Compatibility:
# Ensuring cross-platform compatibility, especially regarding file paths and directory structures, was important to make the function portable across different operating systems. Handling platform-specific quirks and ensuring consistent behavior added complexity to the development process.
